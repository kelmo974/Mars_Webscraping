# %%
from splinter import Browser
from bs4 import BeautifulSoup
from webdriver_manager.chrome import ChromeDriverManager

executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 96.0.4664
# [WDM] - Get LATEST driver version for 96.0.4664
# [WDM] - Driver [/Users/kulini/.wdm/drivers/chromedriver/mac64/96.0.4664.45/chromedriver] found in cache

# %%
url = "https://stackoverflow.com/questions/tagged/python?sort=MostVotes&edited=true"
browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
question_list = []

# %%
def get_summary():
    html = browser.html
    soup = BeautifulSoup(html, 'html.parser')
    question_divs = soup.find_all('div', class_="mln24")
    
    for question in question_divs:
        summary = question.find("a", class_="question-hyperlink").text
        votes = question.find("span", class_="vote-count-post").text
        excerpt = question.find("div", class_="excerpt").text.strip()
        question_dict = {
            "summary": summary,
            "votes": votes,
            "excerpt": excerpt
        }
        question_list.append(question_dict)

# %%
for _ in range(5):
    get_summary()
    browser.links.find_by_partial_text('Next').click()

# %%
question_list
# Out:
# [{'summary': 'What does the "yield" keyword do?',
#   'votes': '11746',
#   'excerpt': "What is the use of the yield keyword in Python? What does it do?\nFor example, I'm trying to understand this code1:\ndef _get_child_candidates(self, distance, min_dist, max_dist):\n    if self._leftchild ..."},
#  {'summary': 'What does the "yield" keyword do?',
#   'votes': '11746',
#   'excerpt': "What is the use of the yield keyword in Python? What does it do?\nFor example, I'm trying to understand this code1:\ndef _get_child_candidates(self, distance, min_dist, max_dist):\n    if self._leftchild ..."},
#  {'summary': 'What does if __name__ == "__main__": do?',
#   'votes': '7240',
#   'excerpt': 'Given the following code, what does the if __name__ == "__main__": do?\n\n# Threading example\nimport time, thread\n\ndef myfunction(string, sleeptime, lock, *args):\n    while True:\n        lock.acquire()\n ...'},
#  {'summary': 'Does Python have a ternary conditional operator?',
#   'votes': '7115',
#   'excerpt': 'If Python does not have a ternary conditional operator, is it possible to simulate one using other language constructs?'},
#  {'summary': 'What are metaclasses in Python?',
#   'votes': '6535',
#   'excerpt': 'In Python, what are metaclasses and what do we use them for?'},
#  {'summary': 'How do I check whether a file exists without exceptions?',
#   'votes': '6486',
#   'excerpt': 'How do I check whether a file exists or not, without using the try statement?'},
#  {'summary': 'How do I merge two dictionaries in a single expression (take union of dictionaries)?',
#   'votes': '6073',
#   'excerpt': 'I have two Python dictionaries, and I want to write a single expression that returns these two dictionaries, merged (i.e. taking the union).  The update() method would be what I need, if it returned ...'},
#  {'summary': 'How to execute a program or call a system command?',
#   'votes': '5571',
#   'excerpt': "How do you call an external command (as if I'd typed it at the Unix shell or Windows command prompt) from within a Python script?"},
#  {'summary': 'How can I safely create a nested directory?',
#   'votes': '5052',
#   'excerpt': 'What is the most elegant way to check if the directory a file is going to be written to exists, and if not, create the directory using Python? Here is what I tried:\nimport os\n\nfile_path = "/my/...'},
#  {'summary': "Accessing the index in 'for' loops?",
#   'votes': '4493',
#   'excerpt': "How do I access the index in a for loop like the following?\n\nints = [8, 23, 45, 12, 78]\nfor i in ints:\n    print('item #{} = {}'.format(???, i))\nI want to get this output:\n\nitem #1 = 8\nitem #2 = 23\n..."},
#  {'summary': 'How to make a flat list out of a list of lists',
#   'votes': '4418',
#   'excerpt': 'Is there a shortcut to make a simple list out of a list of lists in Python?\nI can do it in a for loop, but is there some cool "one-liner"?\nI tried it with functools.reduce():\nfrom functools ...'},
#  {'summary': 'Difference between staticmethod and classmethod',
#   'votes': '4176',
#   'excerpt': 'What is the difference between a function decorated with @staticmethod and one decorated with @classmethod?'},
#  {'summary': 'Understanding slice notation',
#   'votes': '4093',
#   'excerpt': "I need a good explanation (references are a plus) on Python's slice notation. \n\nTo me, this notation needs a bit of picking up. \n\nIt looks extremely powerful, but I haven't quite got my head around it...."},
#  {'summary': 'Finding the index of an item in a list',
#   'votes': '3893',
#   'excerpt': 'Given a list ["foo", "bar", "baz"] and an item in the list "bar", how do I get its index (1) in Python?'},
#  {'summary': "Iterating over dictionaries using 'for' loops",
#   'votes': '3756',
#   'excerpt': "I am a bit puzzled by the following code:\nd = {'x': 1, 'y': 2, 'z': 3} \nfor key in d:\n    print (key, 'corresponds to', d[key])\n\nWhat I don't understand is the key portion. How does Python recognize ..."},
#  {'summary': "Does Python have a string 'contains' substring method?",
#   'votes': '3591',
#   'excerpt': 'I\'m looking for a string.contains or string.indexof method in Python.\n\nI want to do:\n\nif not somestring.contains("blah"):\n   continue'},
#  {'summary': 'Using global variables in a function',
#   'votes': '3556',
#   'excerpt': 'How can I create or use a global variable in a function?\n\nIf I create a global variable in one function, how can I use that global variable in another function? Do I need to store the global variable ...'},
#  {'summary': 'Using global variables in a function',
#   'votes': '3556',
#   'excerpt': 'How can I create or use a global variable in a function?\n\nIf I create a global variable in one function, how can I use that global variable in another function? Do I need to store the global variable ...'},
#  {'summary': 'How do I list all files of a directory?',
#   'votes': '3466',
#   'excerpt': 'How can I list all files of a directory in Python and add them to a list?'},
#  {'summary': 'How to get the current time in Python',
#   'votes': '3438',
#   'excerpt': 'What is the module/method used to get the current time?'},
#  {'summary': 'How do I sort a dictionary by value?',
#   'votes': '3417',
#   'excerpt': 'I have a dictionary of values read from two fields in a database: a string field and a numeric field. The string field is unique, so that is the key of the dictionary.\n\nI can sort on the keys, but how ...'},
#  {'summary': 'Catch multiple exceptions in one line (except block)',
#   'votes': '3378',
#   'excerpt': 'I know that I can do:\n\ntry:\n    # do something that may fail\nexcept:\n    # do this if ANYTHING goes wrong\nI can also do this:\n\ntry:\n    # do something that may fail\nexcept IDontLikeYouException:\n    #...'},
#  {'summary': 'What is the difference between __str__ and __repr__?',
#   'votes': '3248',
#   'excerpt': 'What is the difference between __str__ and __repr__ in Python?'},
#  {'summary': 'How do I check if a list is empty?',
#   'votes': '3231',
#   'excerpt': 'For example, if passed the following:\n\na = []\nHow do I check to see if a is empty?'},
#  {'summary': 'How can I add new keys to a dictionary?',
#   'votes': '3225',
#   'excerpt': "Is it possible to add a key to a Python dictionary after it has been created?\n\nIt doesn't seem to have an .add() method."},
#  {'summary': 'How to iterate over rows in a DataFrame in Pandas',
#   'votes': '3180',
#   'excerpt': "I have a DataFrame from Pandas:\n\nimport pandas as pd\ninp = [{'c1':10, 'c2':100}, {'c1':11,'c2':110}, {'c1':12,'c2':120}]\ndf = pd.DataFrame(inp)\nprint df\nOutput:\n\n   c1   c2\n0  10  100\n1  11  110\n2  ..."},
#  {'summary': 'How do I concatenate two lists in Python?',
#   'votes': '3174',
#   'excerpt': 'How do I concatenate two lists in Python?\n\nExample:\n\nlistone = [1, 2, 3]\nlisttwo = [4, 5, 6]\nExpected outcome:\n\n>>> joinedlist\n[1, 2, 3, 4, 5, 6]'},
#  {'summary': 'How to copy files?',
#   'votes': '3164',
#   'excerpt': "How do I copy a file in Python?\nI couldn't find anything under os\nmodule."},
#  {'summary': 'Convert bytes to a string',
#   'votes': '3153',
#   'excerpt': "I'm using this code to get standard output from an external program:\n\n>>> from subprocess import *\n>>> command_stdout = Popen(['ls', '-l'], stdout=PIPE).communicate()[0]\nThe ..."},
#  {'summary': "What is the difference between Python's list methods append and extend?",
#   'votes': '3113',
#   'excerpt': "What's the difference between the list methods append() and extend()?"},
#  {'summary': 'How can I make a time delay in Python? [duplicate]',
#   'votes': '3040',
#   'excerpt': 'I would like to know how to put a time delay in a Python script.'},
#  {'summary': '"Least Astonishment" and the Mutable Default Argument',
#   'votes': '3039',
#   'excerpt': 'Anyone tinkering with Python long enough has been bitten (or torn to pieces) by the following issue:\ndef foo(a=[]):\n    a.append(5)\n    return a\n\nPython novices would expect this function to always ...'},
#  {'summary': 'What is __init__.py for?',
#   'votes': '3027',
#   'excerpt': 'What is __init__.py for in a Python source directory?'},
#  {'summary': 'What is __init__.py for?',
#   'votes': '3027',
#   'excerpt': 'What is __init__.py for in a Python source directory?'},
#  {'summary': 'How do I pass a variable by reference?',
#   'votes': '3010',
#   'excerpt': "The Python documentation seems unclear about whether parameters are passed by reference or value, and the following code produces the unchanged value 'Original'\n\nclass PassByReference:\n    def ..."},
#  {'summary': 'List changes unexpectedly after assignment. Why is this and how can I prevent it?',
#   'votes': '2989',
#   'excerpt': 'While using new_list = my_list, any modifications to new_list changes my_list every time. Why is this, and how can I clone or copy the list to prevent it?'},
#  {'summary': 'How to make function decorators and chain them together?',
#   'votes': '2985',
#   'excerpt': 'How can I make two decorators in Python that would do the following?\n\n@makebold\n@makeitalic\ndef say():\n   return "Hello"\n...which should return:\n\n"<b><i>Hello</i></b>"\nI\'m ...'},
#  {'summary': 'Understanding Python super() with __init__() methods [duplicate]',
#   'votes': '2922',
#   'excerpt': "I'm trying to understand the use of super(). From the looks of it, both child classes can be created, just fine. \n\nI'm curious to know about the actual difference between the following 2 child classes...."},
#  {'summary': 'What does ** (double star/asterisk) and * (star/asterisk) do for parameters?',
#   'votes': '2873',
#   'excerpt': 'In the following method definitions, what does the * and ** do for param2?\n\ndef foo(param1, *param2):\ndef bar(param1, **param2):'},
#  {'summary': 'How do I select rows from a DataFrame based on column values?',
#   'votes': '2846',
#   'excerpt': "How can I select rows from a DataFrame based on values in some column in Pandas?\nIn SQL, I would use:\nSELECT *\nFROM table\nWHERE column_name = some_value\n\nI tried to look at Pandas' documentation, but ..."},
#  {'summary': 'How to delete a file or folder in Python?',
#   'votes': '2781',
#   'excerpt': 'How do I delete a file or folder in Python?'},
#  {'summary': 'Manually raising (throwing) an exception in Python',
#   'votes': '2748',
#   'excerpt': 'How can I raise an exception in Python so that it can later be caught via an except block?'},
#  {'summary': 'How do you split a list (or iterable) into evenly sized chunks?',
#   'votes': '2735',
#   'excerpt': 'I have a list of arbitrary length, and I need to split it up into equal size chunks and operate on it. There are some obvious ways to do this, like keeping a counter and two lists, and when the second ...'},
#  {'summary': 'How do you change the size of figures drawn with Matplotlib?',
#   'votes': '2731',
#   'excerpt': 'How do you change the size of figure drawn with Matplotlib?'},
#  {'summary': 'Check if a given key already exists in a dictionary',
#   'votes': '2679',
#   'excerpt': 'I wanted to test if a key exists in a dictionary before updating the value for the key.\nI wrote the following code:\n\nif \'key1\' in dict.keys():\n  print "blah"\nelse:\n  print "boo"\nI think this is not ...'},
#  {'summary': 'How to print colored text to the terminal',
#   'votes': '2673',
#   'excerpt': 'How can I output colored text to the terminal in Python?'},
#  {'summary': 'How can I install pip on Windows?',
#   'votes': '2664',
#   'excerpt': 'pip is a replacement for easy_install. But should I install pip using easy_install on Windows? Is there a better way?'},
#  {'summary': 'How to access environment variable values',
#   'votes': '2661',
#   'excerpt': 'I set an environment variable that I want to access in my Python application. How do I get its value?'},
#  {'summary': "Find the current directory and file's directory [duplicate]",
#   'votes': '2656',
#   'excerpt': 'In Python, what commands can I use to find:\n\nthe current directory (where I was in the terminal when I ran the Python script), and\nwhere the file I am executing is?'},
#  {'summary': "Find the current directory and file's directory [duplicate]",
#   'votes': '2656',
#   'excerpt': 'In Python, what commands can I use to find:\n\nthe current directory (where I was in the terminal when I ran the Python script), and\nwhere the file I am executing is?'},
#  {'summary': 'Converting string into datetime',
#   'votes': '2646',
#   'excerpt': "I've got a huge list of date-times like this as strings:\n\nJun 1 2005  1:33PM\nAug 28 1999 12:00AM\nI'm going to be shoving these back into proper datetime fields in a database so I need to magic them ..."},
#  {'summary': 'Why is "1000000000000000 in range(1000000000000001)" so fast in Python 3?',
#   'votes': '2590',
#   'excerpt': 'It is my understanding that the range() function, which is actually an object type in Python 3, generates its contents on the fly, similar to a generator.\nThis being the case, I would have expected ...'},
#  {'summary': 'How do I parse a string to a float or int?',
#   'votes': '2557',
#   'excerpt': 'In Python, how can I parse a numeric string like\n"545.2222" \n\nto its corresponding float value,\n545.2222\n\n? Or parse the string "31" to an integer, 31?\nI just want to know how to ...'},
#  {'summary': 'How to get the last element of a list',
#   'votes': '2504',
#   'excerpt': 'In Python, how do you get the last element of a list?'},
#  {'summary': 'How do I get a substring of a string in Python?',
#   'votes': '2448',
#   'excerpt': "Is there a way to substring a string in Python, to get a new string from the third character to the end of the string?\n\nMaybe like myString[2:end]?\n\nIf leaving the second part means 'till the end', ..."},
#  {'summary': 'How to upgrade all Python packages with pip',
#   'votes': '2427',
#   'excerpt': 'Is it possible to upgrade all Python packages at one time with pip?\nNote: that there is a feature request for this on the official issue tracker.'},
#  {'summary': 'Renaming column names in Pandas',
#   'votes': '2426',
#   'excerpt': "I have a DataFrame using Pandas and column labels that I need to edit to replace the original column labels.\nI'd like to change the column names in a DataFrame A where the original column names are:\n['..."},
#  {'summary': 'How can I remove a key from a Python dictionary?',
#   'votes': '2403',
#   'excerpt': "When deleting a key from a dictionary, I use:\nif 'key' in my_dict:\n    del my_dict['key']\n\nIs there a one line way of doing this?"},
#  {'summary': 'How do I sort a list of dictionaries by a value of the dictionary?',
#   'votes': '2374',
#   'excerpt': "I have a list of dictionaries and want each item to be sorted by a specific value.\nTake into consideration the list:\n[{'name':'Homer', 'age':39}, {'name':'Bart', 'age':10}]\n\nWhen sorted by name, it ..."},
#  {'summary': 'How do I lowercase a string in Python?',
#   'votes': '2367',
#   'excerpt': 'Is there a way to convert a string from uppercase, or even part uppercase to lowercase? \n\nFor example, "Kilometers" → "kilometers".'},
#  {'summary': 'Are static class variables possible in Python?',
#   'votes': '2280',
#   'excerpt': 'Is it possible to have static class variables or methods in Python? What syntax is required to do this?'},
#  {'summary': 'How to print without a newline or space',
#   'votes': '2202',
#   'excerpt': 'I\'d like to do it in Python. What I\'d like to do in this example in C:\n#include <stdio.h>\n\nint main() {\n    int i;\n    for (i=0; i<10; i++) printf(".");\n    return 0;\n}\n\nOutput:\n.......'},
#  {'summary': 'How do I get the number of elements in a list',
#   'votes': '2145',
#   'excerpt': 'Consider the following:\n\nitems = []\nitems.append("apple")\nitems.append("orange")\nitems.append("banana")\n\n# FAKE METHOD:\nitems.amount()  # Should return 3\nHow do I get the number of elements in the ...'},
#  {'summary': 'Calling a function of a module by using its name (a string)',
#   'votes': '2131',
#   'excerpt': 'What is the best way to go call a function, given a string with the function\'s name in a Python program. For example, let\'s say that I have a module foo, and I have a string whose content is "bar&...'},
#  {'summary': 'How to know if an object has an attribute in Python',
#   'votes': '2096',
#   'excerpt': 'Is there a way in Python to determine if an object has some attribute?  For example:\n\n>>> a = SomeClass()\n>>> a.someProperty = value\n>>> a.property\nTraceback (most recent ...'},
#  {'summary': 'How to know if an object has an attribute in Python',
#   'votes': '2096',
#   'excerpt': 'Is there a way in Python to determine if an object has some attribute?  For example:\n\n>>> a = SomeClass()\n>>> a.someProperty = value\n>>> a.property\nTraceback (most recent ...'},
#  {'summary': 'How can I randomly select an item from a list?',
#   'votes': '2095',
#   'excerpt': "Assume I have the following list:\nfoo = ['a', 'b', 'c', 'd', 'e']\n\nWhat is the simplest way to retrieve an item at random from this list?"},
#  {'summary': 'Is there a way to run Python on Android?',
#   'votes': '2088',
#   'excerpt': 'We are working on an S60 version and this platform has a nice Python API..\n\nHowever, there is nothing official about Python on Android, but since Jython exists, is there a way to let the snake and the ...'},
#  {'summary': 'Limiting floats to two decimal points',
#   'votes': '2052',
#   'excerpt': 'I want a to be rounded to 13.95.\n\n>>> a\n13.949999999999999\n>>> round(a, 2)\n13.949999999999999\nThe round function does not work the way I expected.'},
#  {'summary': 'Why is reading lines from stdin much slower in C++ than Python?',
#   'votes': '2049',
#   'excerpt': 'I wanted to compare reading lines of string input from stdin using Python and C++ and was shocked to see my C++ code run an order of magnitude slower than the equivalent Python code. Since my C++ is ...'},
#  {'summary': 'How to leave/exit/deactivate a Python virtualenv',
#   'votes': '2044',
#   'excerpt': "I'm using virtualenv and the virtualenvwrapper. I can switch between virtualenv's just fine using the workon command.\nme@mymachine:~$ workon env1\n(env1)me@mymachine:~$ workon env2\n(env2)me@mymachine:~$..."},
#  {'summary': 'How to read a file line-by-line into a list?',
#   'votes': '2026',
#   'excerpt': 'How do I read every line of a file in Python and store each line as an element in a list? \n\nI want to read the file line by line and append each line to the end of the list.'},
#  {'summary': 'Importing files from different folder',
#   'votes': '2005',
#   'excerpt': 'I have the following folder structure.\napplication\n├── app\n│\xa0\xa0 └── folder\n│\xa0\xa0     └── file.py\n└── app2\n    └── some_folder\n        └── some_file.py\n\nI want to import some functions from file.py in ...'},
#  {'summary': 'How can I print literal curly-brace characters in a string and also use .format on it?',
#   'votes': '1989',
#   'excerpt': 'x = " \\{ Hello \\} {0} "\nprint(x.format(42))\ngives me : Key Error: Hello\\\\\n\nI want to print the output: {Hello} 42'},
#  {'summary': 'Determine the type of an object?',
#   'votes': '1985',
#   'excerpt': 'Is there a simple way to determine if a variable is a list, dictionary, or something else? I am getting an object back that may be either type and I need to be able to tell the difference.'},
#  {'summary': 'Why is it string.join(list) instead of list.join(string)?',
#   'votes': '1945',
#   'excerpt': 'This has always confused me. It seems like this would be nicer:\n\nmy_list = ["Hello", "world"]\nprint(my_list.join("-"))\n# Produce: "Hello-world"\nThan this:\n\nmy_list = ["Hello", "world"]\nprint("-".join(...'},
#  {'summary': "How to determine a Python variable's type?",
#   'votes': '1936',
#   'excerpt': 'How do I see the type of a variable whether it is unsigned 32 bit, signed 16 bit, etc.?\n\nHow do I view it?'},
#  {'summary': 'How to remove an element from a list by index',
#   'votes': '1909',
#   'excerpt': 'How do I remove an element from a list by index in Python?\n\nI found the list.remove method, but say I want to remove the last element, how do I do this? It seems like the default remove searches the ...'},
#  {'summary': 'How can I count the occurrences of a list item?',
#   'votes': '1906',
#   'excerpt': 'Given an item, how can I count its occurrences in a list in Python?'},
#  {'summary': 'How can I remove a trailing newline?',
#   'votes': '1887',
#   'excerpt': "What is the Python equivalent of Perl's chomp function, which removes the last character of a string if it is a newline?"}]

# %%
browser.quit()
